# %%
import matplotlib.pyplot as plt
import csv

y_real_FFT = []
y_img_FFT = []
y_comb_FFT = []

x_FFT = []

with open('FFTSpectrum.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    counter = 0
    
    firstrow = True
    for row in plots:
        
        if firstrow:
            firstrow = False
            continue
            
        y_real_FFT.append(float(row[0]))
        y_img_FFT.append(float(row[1]))
        y_comb_FFT.append(float(row[2]))

        x_FFT.append(counter)
        counter = counter + 1

# %%
plt.plot(x_FFT,y_comb_FFT, label='FFT Spectrum')
plt.xlabel('mass')
plt.ylabel('intensity real')
plt.title('FFT Spectrum')
plt.legend()
plt.show()

plt.plot(x_FFT,y_real_FFT, label='FFT Spectrum')
plt.xlabel('mass')
plt.ylabel('intensity real')
plt.title('FFT Spectrum')
plt.legend()
plt.show()

plt.plot(x_FFT,y_img_FFT, label='FFT Spectrum')
plt.xlabel('mass')
plt.ylabel('intensity real')
plt.title('FFT Spectrum')
plt.legend()
plt.show()

# %%
   
yComb = []
xComb = []

with open('CombinedSpectrum.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    counter = 0
    
    for row in plots:
            
        yComb.append(float(row[0])/1000)
        xComb.append(counter)
        
        print("X: {}, Y: {}".format(xComb, yComb))
        
        counter = counter+1
        

    print(counter)

# %%
plt.figure(figsize=(20,10))

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = plt.hist(xComb, bins=100)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

# We can also normalize our inputs by the total number of counts
plt.hist(xComb, bins=100, density=True)

plt.show()

# %%
plt.plot(xComb,yComb, label='Combined Spectrum')
plt.xlabel('mass')
plt.ylabel('intensity real')
plt.title('FFT Spectrum')
plt.legend()
plt.show()

# %%
from matplotlib import colors

n_bins = 100

def plotGraph(x,y):
        plt.figure(figsize=(20,10))
        plt.plot(mass,intensity, label='IndividualSpectrum')
        plt.xlabel('Mass')
        plt.ylabel('Intensity')
        plt.title('FFT Spectrum Individual')
        plt.legend()
        plt.show()
        
def plotHist(x,y):
    plt.figure(figsize=(20,10))

    # N is the count in each bin, bins is the lower-limit of the bin
    N, bins, patches = plt.hist(x, bins=n_bins)

    # We'll color code by height, but you could use any scalar
    fracs = N / N.max()
    
    # we need to normalize the data to 0..1 for the full range of the colormap
    norm = colors.Normalize(fracs.min(), fracs.max())

    # Now, we'll loop through our objects and set the color of each accordingly
    for thisfrac, thispatch in zip(fracs, patches):
        color = plt.cm.viridis(norm(thisfrac))
        thispatch.set_facecolor(color)

    # We can also normalize our inputs by the total number of counts
    plt.hist(x, bins=n_bins, density=True)

    plt.show()
    
        
        
for i in range(10):
    with open('Spec/IndividualSpectrum{}.csv'.format(i),'r') as csvfile:
        plots = csv.reader(csvfile, delimiter=',')

        intensity = []
        mass = []
        firstRow = True;
        
        count = 0
        
        for row in plots:
            
            if firstRow:
                firstRow = False
                continue
                
            mass.append(int( round(float(row[0])) ))
            intensity.append(round(float(row[1]),2))
            
            count = count + 1
                        
        plotHist(mass, intensity)
        plotGraph(mass, intensity)
